# %%
from dulu import OCR
from PIL import Image

# %%
image = Image.open("./sample_image.png")
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=518x737>

# %%
ocr = OCR()

# %%
ocr.recognize_text("./sample_image.png",bbox=False)
# Out:
# 'Gareth James. Daniela Witten.revor Hastie. Robert Tibshirani. Jonathan Taylor An Introduction to Statistics Learning with Applications in Python Springer'

# %%
ocr.recognize_text("./sample_image.png")
# Out:
# {'<OCR_WITH_REGION>': {'quad_boxes': [[60.8650016784668,
#     197.14749145507812,
#     456.61700439453125,
#     197.14749145507812,
#     456.61700439453125,
#     222.94248962402344,
#     60.8650016784668,
#     222.94248962402344],
#    [60.8650016784668,
#     225.15350341796875,
#     360.7870178222656,
#     225.15350341796875,
#     360.7870178222656,
#     253.1595001220703,
#     60.8650016784668,
#     252.42250061035156],
#    [60.8650016784668,
#     282.6394958496094,
#     468.01300048828125,
#     282.6394958496094,
#     468.01300048828125,
#     348.969482421875,
#     60.8650016784668,
#     348.969482421875],
#    [59.829002380371094,
#     360.7615051269531,
#     381.50701904296875,
#     360.7615051269531,
#     381.50701904296875,
#     426.3544921875,
#     59.829002380371094,
#     426.3544921875],
#    [62.419002532958984,
#     437.40948486328125,
#     289.8210144042969,
#     441.094482421875,
#     288.7850036621094,
#     517.0054931640625,
# ...
